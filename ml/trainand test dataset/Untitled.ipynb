# %%
import pandas as pd
df=pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df["Mileage"],df["Sell Price($)"],marker="+",color="red")

# %%
plt.scatter(df["Age(yrs)"],df["Sell Price($)"])

# %%
X=df[["Mileage","Age(yrs)"]]
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y=df[["Sell Price($)"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [raw]
# due to random_state=10 it will be changing all the time

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 2     57000         5
# 13    58780         4
# 7     72000         6
# 10    83000         7
# 3     22500         2
# 6     52000         5
# 5     59000         5
# 0     69000         6
# 16    28000         2
# 11    79000         7
# 9     67000         6
# 19    52000         5
# 8     91000         8
# 1     35000         3
# 4     46000         4
# 14    82450         7

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 17    69000         5
# 18    87600         8
# 15    25400         3
# 12    59000         5

# %%
y_test
# Out:
#     Sell Price($)
# 17          19700
# 18          12800
# 15          35000
# 12          26000

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 17    69000         5
# 18    87600         8
# 15    25400         3
# 12    59000         5

# %%
reg.predict(X_test)
# Out:
# array([[22129.26035156],
#        [15295.96554742],
#        [38372.53697471],
#        [25875.33302903]])

# %%
reg.score(X_test,y_test)
# Out:
# 0.9120285847420287
